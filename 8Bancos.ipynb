# %% [markdown]
# Faça uma programa que simule uma memória com 8 bancos e com capacidade de 32 células, como está na figura abaixo mostrada nos slides. A MPController recebe um endereço, determina qual é o banco através dos bits do endereço e em seguida determina a célula usando os bits da linha e da coluna. Antes da execução preencher a MP com valores binários aleatórios ou escolhidos por vocês. Manter no projeto final a função runSimulation e fazer tudo dentro dela. Ela recebe todos os argumentos e redistribui para as outras funções. Antes de chamá-la, peçam ao usuário (processador) o endereço a ser usado.

# %%
def MPController( ):
    return False; #Apenas para servir de protótipo. 
def runSimulation( ):
    if MPController( ):
        print("Conteúdo da célula: xxxxxx")
        return
    #Early return - não uso else
    print("Endereço incorreto.")

# %%
from IPython.display import Image



Image(filename='8bancos.png')
